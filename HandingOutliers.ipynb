# %% [markdown]
# <a href="https://colab.research.google.com/github/beingdeveloper21/feature_Engineer/blob/main/HandingOutliers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#In this document we will learn about
#5 NUMBER SUMMARY AND BOX PLOT

# %%
#MININMUM,Q1,MEDIAN,Q3,MAXIMUM

# %%
import numpy as np
lst_marks=[45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74]
min,Q1,median,Q3,max=np.quantile(lst_marks,[0,0.25,0.5,0.75,1])

# %%
min,Q1,median,Q3,max
# Out:
# (np.float64(32.0),
#  np.float64(54.0),
#  np.float64(67.0),
#  np.float64(89.0),
#  np.float64(99.0))

# %%
IQR=Q3-Q1
print(IQR)
# Out:
# 35.0

# %%
lower_fence=Q1-1.5*IQR
higher_fence=Q3+1.5*IQR
print(lower_fence,higher_fence)
# Out:
# 1.5 141.5

# %%
import seaborn as sns
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks=[-20,5,45,32,56,75,89,54,32,89,90,87,67,54,45,98,99,67,74,150,180,200]

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >
